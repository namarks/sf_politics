# %%
import sys
import pandas as pd
import graph_tool.all as gt
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# # Example Plot

# %%
g = gt.Graph()

v1 = g.add_vertex()
v2 = g.add_vertex()
v3 = g.add_vertex()
e1 = g.add_edge(v1, v2)
e2 = g.add_edge(v2, v3)
e3 = g.add_edge(v3, v1)

# Step 5: Assign properties (optional)
vprop = g.new_vertex_property("string")
vprop[v1] = "A"
vprop[v2] = "B"
vprop[v3] = "C"
g.vertex_properties["label"] = vprop

# Step 6: Visualize the graph
gt.graph_draw(g, vertex_text=g.vertex_properties["label"], output_size=(300, 300))
# Out:
# <VertexPropertyMap object with value type 'vector<double>', for Graph 0x323b7b770, at 0x10534fe00>
